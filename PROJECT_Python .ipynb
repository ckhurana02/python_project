# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Automobile_data (1).csv")
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df = df.replace('?',np.NaN) 
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df.shape
# Out:
# (205, 26)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df["price"]=df["price"].astype("float")
print(df["price"])

df["bore"]=df["bore"].astype("float")
print(df["bore"])

df["stroke"]=df["stroke"].astype("float")
print(df["stroke"])

df["peak-rpm"]=df["peak-rpm"].astype("float")
print(df["peak-rpm"])

df["horsepower"]=df["horsepower"].astype("float")
print(df["horsepower"])
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 205, dtype: float64
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: float64
# 0      5000.0
# 1      5000.0
# 2      5000.0
# 3      5500.0
# 4      5500.0
#         ...
# 200    5400.0
# 201    5300.0
# 202    5500.0
# 203    4800.0
# 204    5400.0
# Name: peak-rpm, Length: 205, dtype: float64
# 0      111.0
# 1      111.0
# 2      154.0
# 3      102.0
# 4      115.0
#        ...
# 200    114.0
# 201    160.0
# 202    134.0
# 203    106.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size        bore      stroke  compression-ratio  \
# count   205.000000   205.000000  201.000000  201.000000         205.000000
# mean   2555.565854   126.907317    3.329751    3.255423          10.142537
# std     520.680204    41.642693    0.273539    0.316717           3.972040
# ...

# %%
d=df.select_dtypes(['int64','float64'])
d
# Out:
#      symboling  wheel-base  length  width  height  curb-weight  engine-size  \
# 0            3        88.6   168.8   64.1    48.8         2548          130
# 1            3        88.6   168.8   64.1    48.8         2548          130
# 2            1        94.5   171.2   65.5    52.4         2823          152
# 3            2        99.8   176.6   66.2    54.3         2337          109
# 4            2        99.4   176.6   66.4    54.3         2824          136
# ..         ...         ...     ...    ...     ...          ...          ...
# 200         -1       109.1   188.8   68.9    55.5         2952          141
# 201         -1       109.1   188.8   68.8    55.5         3049          141
# 202         -1       109.1   188.8   68.9    55.5         3012          173
# 203         -1       109.1   188.8   68.9    55.5         3217          145
# 204         -1       109.1   188.8   68.9    55.5         3062          141
#
# ...

# %%
f=df.select_dtypes("object")
f
# Out:
#     normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                 NaN  alfa-romero       gas        std          two
# 1                 NaN  alfa-romero       gas        std          two
# 2                 NaN  alfa-romero       gas        std          two
# 3                 164         audi       gas        std         four
# 4                 164         audi       gas        std         four
# ..                ...          ...       ...        ...          ...
# 200                95        volvo       gas        std         four
# 201                95        volvo       gas      turbo         four
# 202                95        volvo       gas        std         four
# 203                95        volvo    diesel      turbo         four
# 204                95        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location engine-type num-of-cylinders  \
# ...

# %% [markdown]
# # Cars of which Company available in dataset

# %%
df["make"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %% [markdown]
# # How many cars of each company

# %%
df["make"].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# volvo            11
# peugot           11
# dodge             9
# bmw               8
# mercedes-benz     8
# plymouth          7
# audi              7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
plt.figure(figsize=(27,16))
sns.set_style("white")
plt.title("No. of make frequency diagram",size=28,color="green")
plt.xlabel("make",size=25)
plt.ylabel("count",size=25)
sns.countplot(data=df,x="make",edgecolor="black",palette="Paired")
c=df["make"].value_counts()
plt.yticks(c,size=16)
plt.xticks(color="maroon",size=15,rotation=12)

plt.show()

# %%
plt.figure(figsize=(16,8))
sns.set_style("dark")
plt.xticks(size=12,color="brown")
plt.yticks(size=12)
plt.xlabel("body-style",size=16,color="green")
plt.ylabel("count",size=16,color="green")
plt.title("No. of make Frequency Diagram on the basis of body-style",size=20,color="purple")
sns.set_style("dark")
plt.xticks(rotation=20)
sns.countplot(data=df,x="make",hue="body-style",palette="icefire") 
plt.show()

# %% [markdown]
# #  The maximum price of car and record no of maximum price of car

# %%
print("The maximum price of car is:")
print(df["price"].max())
print("\n")
print("The record no of maximum price of car: ")
print(df["price"].idxmax())
# Out:
# The maximum price of car is:
# 45400.0
#
#
# The record no of maximum price of car:
# 74

# %% [markdown]
# # The minimum price of car and record no of maximum price of car

# %%
print("The minimum price of car is:")
print(df["price"].min())
print("\n")
print("The record no of minimum price of car: ")
print(df["price"].idxmin())
# Out:
# The minimum price of car is:
# 5118.0
#
#
# The record no of minimum price of car:
# 138

# %% [markdown]
# # Total sum of price of car for each category of body-style

# %%
df["body-style"].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df["body-style"].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
print("Total sum of price of car for each category of body-style:")
df.groupby("body-style")["price"].sum()
# Out:
# Total sum of price of car for each category of body-style:
# body-style
# convertible     131343.0
# hardtop         177668.0
# hatchback       677106.0
# sedan          1359217.0
# wagon           309299.0
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,10))
explode=(0,0,0,0,0.3)
df["body-style"].value_counts().plot(kind="pie",explode=explode,autopct="%.1f%%",shadow=True,startangle=90,colors=["blue","green","pink","cyan","orange"])
plt.show()

# %% [markdown]
# # Average price of car according to the body-style and fuel-type

# %%
df.groupby(["body-style","fuel-type"])["price"].mean()
# Out:
# body-style   fuel-type
# convertible  gas          21890.500000
# hardtop      diesel       28176.000000
#              gas          21356.000000
# hatchback    diesel        7788.000000
#              gas           9989.820896
# sedan        diesel       14774.400000
#              gas          14400.012658
# wagon        diesel       19727.666667
#              gas          11368.909091
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,7))
plt.xticks(size=12,color="blue")
plt.yticks(size=12)
plt.xlabel("body-style",size=16,color="orange")
plt.ylabel("count",size=16,color="orange")
plt.title("Body-style Frequency Diagram on the basis of fuel-type",size=20,color="navy")
sns.set_style("darkgrid")
plt.xticks(rotation=10)
sns.countplot(data=df,x="body-style",hue="fuel-type",palette="husl") 
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set_style("darkgrid")
plt.xlabel("body-style",size=16)
plt.ylabel("price",size=16)
plt.xticks(color="navy",size=12)
plt.yticks(color="maroon",size=10)
plt.title("Bar plot of body-type vs price on the basis of fuel-type",size=21,color="brown")
plt.xticks(rotation=15)
sns.barplot(data=df,x="body-style",y="price",hue="fuel-type",palette="Set2") 
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.xticks(size=12,color="red")
plt.yticks(size=12)
plt.xlabel("body-style",size=16,color="purple")
plt.ylabel("count",size=16,color="purple")
plt.title("Body-style Frequency Diagram on the basis of num-of-doors",size=20,color="black")
sns.set_style("whitegrid")
plt.xticks(rotation=10)
sns.countplot(data=df,x="body-style",hue="num-of-doors",palette="vlag") 
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.set_style("dark")
plt.subplot(2,2,1)
plt.xlabel("width",size=16)
plt.ylabel("price",size=16)
sns.scatterplot(data=df,x="width",y="price",hue="body-style")

plt.subplot(2,2,2)
plt.xlabel("height",size=16)
plt.ylabel("price",size=16)
sns.scatterplot(data=df,x="height",y="price",hue="body-style")

plt.subplot(2,2,3)
plt.xlabel("length",size=16)
plt.ylabel("price",size=16)
sns.scatterplot(data=df,x="length",y="price",hue="body-style")

plt.subplot(2,2,4)
plt.xlabel("engine-size",size=16)
plt.ylabel("price",size=16)
sns.scatterplot(data=df,x="engine-size",y="price",hue="body-style")

plt.suptitle("Price Analysis with width,height,length and engine size on the basis of body-style",size=23,color="orange")
plt.show()

# %% [markdown]
# # How many fuel-type of cars

# %%
df["fuel-type"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
print("No. of fuel type car : ")
df["fuel-type"].value_counts()
# Out:
# No. of fuel type car :
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64

# %%
plt.figure(figsize=(10,7))
df["fuel-type"].value_counts().plot(kind="pie",explode=(0,0.3),autopct="%.2f%%",shadow=True,startangle=90,colors=["yellow","red"])
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.xticks(size=12,color="blue")
plt.yticks(size=12)
plt.xlabel("body-style",size=16,color="orange")
plt.ylabel("count",size=16,color="orange")
plt.title("Make Frequency Diagram on the basis of fuel-type",size=20,color="green")
sns.set_style("dark")
plt.xticks(rotation=20)
sns.countplot(data=df,x="make",hue="fuel-type",palette="rocket") 
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.xticks(size=12,color="purple")
plt.yticks(size=12)
plt.xlabel("body-style",size=16,color="black")
plt.ylabel("count",size=16,color="black")
plt.title("Make Frequency Diagram on the basis of num-of-doors",size=20,color="red")
sns.set_style("white")
plt.xticks(rotation=20)
sns.countplot(data=df,x="make",hue="num-of-doors",palette="viridis") 
plt.show()

# %% [markdown]
# # To display those car's details whose fuel-type is diesel and body-style is sedan and having num of doors four and also city-mpg is greater than 25

# %%
df[(df["fuel-type"]=="diesel")&(df["body-style"]=="sedan")&(df["num-of-doors"]=="four")&(df["city-mpg"]>25)]
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 66           0               NaN       mazda    diesel        std
# 108          0               161      peugot    diesel      turbo
# 112          0               161      peugot    diesel      turbo
# 116          0               161      peugot    diesel      turbo
# 158          0                91      toyota    diesel        std
# 174         -1                65      toyota    diesel      turbo
# 184          2                94  volkswagen    diesel        std
# 187          2                94  volkswagen    diesel      turbo
# 192          0               NaN  volkswagen    diesel      turbo
# 203         -1                95       volvo    diesel      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 66          four      sedan          rwd           front       104.9  ...
# 108         four      sedan          rwd           front       107.9  ...
# ...

# %%
d=df.select_dtypes(['int64','float64'])
d
# Out:
#      symboling  wheel-base  length  width  height  curb-weight  engine-size  \
# 0            3        88.6   168.8   64.1    48.8         2548          130
# 1            3        88.6   168.8   64.1    48.8         2548          130
# 2            1        94.5   171.2   65.5    52.4         2823          152
# 3            2        99.8   176.6   66.2    54.3         2337          109
# 4            2        99.4   176.6   66.4    54.3         2824          136
# ..         ...         ...     ...    ...     ...          ...          ...
# 200         -1       109.1   188.8   68.9    55.5         2952          141
# 201         -1       109.1   188.8   68.8    55.5         3049          141
# 202         -1       109.1   188.8   68.9    55.5         3012          173
# 203         -1       109.1   188.8   68.9    55.5         3217          145
# 204         -1       109.1   188.8   68.9    55.5         3062          141
#
# ...

# %%
column=d.columns
print(column)
print("\n")
y=len(column)
y=y-1
column=column[:y]
print(column)

print("\n")
Y=d["price"]  
plt.figure(figsize=(22,32))
sns.set_style("dark")
plt.suptitle("Price Analysis",size=23,color="black")
for i,col in enumerate(column):
    X=d[col]
    plt.subplot(5,3,i+1)
    plt.scatter(X,Y,color="green")
    plt.xlabel(col,size=16) 
    plt.xticks(size=12)
    plt.ylabel("price",size=16)
    plt.yticks(size=12)
plt.show()
# Out:
# Index(['symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight',
#        'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')
#
#
# Index(['symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight',
#        'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'city-mpg', 'highway-mpg'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
plt.title("Bar plot of Body-style vs Price on the basis of aspiration",size=18,color="indigo")
sns.set_style("whitegrid")
plt.xticks(rotation=10,color="red",size=14)
plt.xlabel("body-style",size=14)
plt.yticks(color="orange",size=12)
plt.ylabel("price",size=15)
sns.barplot(data=df,x="body-style",y="price",hue="aspiration",palette="hls") 
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.xticks(size=12,color="blue")
plt.yticks(size=12)
plt.xlabel("body-style",size=16,color="red")
plt.ylabel("count",size=16,color="brown")
plt.title("Body-style Frequency Diagram on the basis of drive-wheels",size=20,color="green")
sns.set_style("darkgrid")
plt.xticks(rotation=10)
sns.countplot(data=df,x="body-style",hue="drive-wheels",palette="tab10") 
plt.show()

# %%
plt.figure(figsize=(12,14))
sns.set_style("darkgrid")

plt.subplot(3,2,1)
sns.distplot(df["engine-size"],kde=False,bins=7,color="orange") 
plt.subplot(3,2,2)
sns.distplot(df["peak-rpm"],kde=False,bins=7,color="red") 

plt.subplot(3,2,3)
sns.distplot(df["curb-weight"],kde=False,bins=7,color="green") 
plt.subplot(3,2,4)
sns.distplot(df["horsepower"],kde=False,bins=7,color="yellow") 
plt.subplot(3,2,5)
sns.distplot(df["city-mpg"],kde=False,bins=7,color="brown")

plt.subplot(3,2,6)
sns.distplot(df["price"],kde=True,bins=7,color="purple") 
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.xlabel("body-style",size=14)
plt.ylabel("price",size=14)
plt.xticks(color="red",size=12)
plt.yticks(size=10)
sns.boxplot(data=df,x="body-style", y="price")
plt.show()

print("\n")

plt.figure(figsize=(12,8))
plt.xlabel("body-style",size=14)
plt.ylabel("price",size=14)
plt.xticks(color="orange",size=12)
plt.yticks(size=10)
sns.boxplot(data=df,x="drive-wheels", y="price")
plt.show()
